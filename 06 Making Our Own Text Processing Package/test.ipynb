# %%
import text_preprocessing as tp

# %%
x = 'I am Currently learning Machine learning and Deep learning Algorithms and many more things.'

# %%
x = ' '.join(list(x))
x
# Out:
# 'I       a   m       C   u   r   r   e   n   t   l   y       l   e   a   r   n   i   n   g       M   a   c   h   i   n   e       l   e   a   r   n   i   n   g       a   n   d       D   e   e   p       l   e   a   r   n   i   n   g       A   l   g   o   r   i   t   h   m   s       a   n   d       m   a   n   y       m   o   r   e       t   h   i   n   g   s   .'

# %%
tp.char_count(x)
# Out:
# 78

# %%
tp.avg_word_len(x)
# Out:
# 5.571428571428571

# %%
tp.stop_words_count(x)
# Out:
# 6
