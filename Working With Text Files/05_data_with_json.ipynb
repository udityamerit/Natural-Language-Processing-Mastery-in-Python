# %%
import pandas as pd
url = 'https://github.com/laxmimerit/All-CSV-ML-DATA-Files-Download/raw/master/Data%20-%20Multiple%20Worksheets.xlsx'
df = pd.read_excel(url, sheet_name = 'Data 1')
df
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
import json

# %%
df.to_json('data/output.json', orient = 'records')

# %%
df.to_json('data/output1.json', orient = 'records', lines = True)

# %%
d1 = json.load(open('data/output.json'))
pd.DataFrame(d1)
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
d1 = pd.read_json('data/output.json')
d1
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
df2 = pd.read_json('data/output1.json', lines=True)
df2
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %% [markdown]
# ### Working with the nested json data

# %%
nested_data = {
        'passenger': {
                'name': 'bob',
                'age': 23,
                'ticket':{
                        'number':'23sdlfj',
                        'price':123
                }
        }
}

# %% [markdown]
# ### How you read or show the nested json in the DataFrame

# %%
pd.json_normalize(nested_data)
# Out:
#   passenger.name  passenger.age passenger.ticket.number  \
# 0            bob             23                 23sdlfj
#
#    passenger.ticket.price
# 0                     123
